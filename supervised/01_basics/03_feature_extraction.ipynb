# %% [markdown]
# <a href="https://colab.research.google.com/github/Lukas-Swc/machine-learning-bootcamp/blob/main/supervised/01_basics/03_feature_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **scikit-learn**
#
# Strona biblioteki: https://scikit-learn.org
#
# Dokumentacja/User Guide: https://scikit-learn.org/stable/user_guide.html
#
# Podstawowa biblioteka do uczenia maszynowego w języku Python.
#
# Aby zainstalować bibliotekę scikit-learn, użyj polecenia poniżej:
#
#   `!pip install scikit-learn`
#
# Aby zaktualizować do najnowszej wersji bibliotekę scikit-learn, użyj polecenia poniżej:
#
#   `!pip install --upgrade scikit-learn`
#
# Kurs stworzony w oparciu o wersję 1.5.2

# %% [markdown]
# # Spis tresci
#
# 1. [Import bibliotek](#0)
# 2. [Zaladowanie danych](#1)
# 3. [Utworzenie kopii danych](#2)
# 4. [Generowanie nowych zmiennych](#3)
# 5. [Dyskretyzacja zmiennej ciaglej](#4)
# 6. [Ekstrakcja cech](#5)

# %% [markdown]
# ### <a name='0'></a> Import bibliotek

# %%
import numpy as np
import pandas as pd
import sklearn

sklearn.__version__
# Out:
# '1.5.2'

# %% [markdown]
# ### <a name='1'></a> Zaladowanie danych

# %%
def fetch_financial_data(company='AMZN'):
  """
  This function fetches stock market quotations.
  """
  import pandas_datareader.data as web
  return web.DataReader(name=company, data_source='stooq')

df_raw = fetch_financial_data()
df_raw.head()
# Out:
#                Open      High      Low   Close    Volume
# Date
# 2024-11-01  198.860  200.5000  197.020  197.93  99687847
# 2024-10-31  190.510  190.6000  185.230  186.40  75146759
# 2024-10-30  194.695  195.6100  192.420  192.73  37707550
# 2024-10-29  188.580  191.4599  187.815  190.83  35690158
# 2024-10-28  189.565  190.2100  188.210  188.39  27930836

# %% [markdown]
# ### <a name='2'></a> Utworzenie kopii danych

# %%
df = df_raw.copy()
df = df[:5]
df['Volume'] = df['Volume'].astype('float')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5 entries, 2024-11-01 to 2024-10-28
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    5 non-null      float64
#  1   High    5 non-null      float64
#  2   Low     5 non-null      float64
#  3   Close   5 non-null      float64
#  4   Volume  5 non-null      float64
# dtypes: float64(5)
# memory usage: 240.0 bytes

# %% [markdown]
# ### <a name='3'></a> Generowanie nowych zmiennych

# %%
df.index
# Out:
# DatetimeIndex(['2024-11-01', '2024-10-31', '2024-10-30', '2024-10-29',
#                '2024-10-28'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
df['day'] = df.index.day
df['month'] = df.index.month
df['year'] = df.index.year
df
# Out:
#                Open      High      Low   Close      Volume  day  month  year
# Date
# 2024-11-01  198.860  200.5000  197.020  197.93  99687847.0    1     11  2024
# 2024-10-31  190.510  190.6000  185.230  186.40  75146759.0   31     10  2024
# 2024-10-30  194.695  195.6100  192.420  192.73  37707550.0   30     10  2024
# 2024-10-29  188.580  191.4599  187.815  190.83  35690158.0   29     10  2024
# 2024-10-28  189.565  190.2100  188.210  188.39  27930836.0   28     10  2024

# %% [markdown]
# ### <a name='4'></a> Dyskretyzacja zmiennej ciaglej

# %%
df = pd.DataFrame(data={'height': [175., 178.5, 185., 191., 184.5, 183., 168.]})
df
# Out:
#    height
# 0   175.0
# 1   178.5
# 2   185.0
# 3   191.0
# 4   184.5
# 5   183.0
# 6   168.0

# %%
df['height_cat'] = pd.cut(x=df.height, bins=3)
df
# Out:
#    height          height_cat
# 0   175.0  (167.977, 175.667]
# 1   178.5  (175.667, 183.333]
# 2   185.0    (183.333, 191.0]
# 3   191.0    (183.333, 191.0]
# 4   184.5    (183.333, 191.0]
# 5   183.0  (175.667, 183.333]
# 6   168.0  (167.977, 175.667]

# %%
df['height_cat'] = pd.cut(x=df.height, bins=(160, 175, 180, 195))
df
# Out:
#    height  height_cat
# 0   175.0  (160, 175]
# 1   178.5  (175, 180]
# 2   185.0  (180, 195]
# 3   191.0  (180, 195]
# 4   184.5  (180, 195]
# 5   183.0  (180, 195]
# 6   168.0  (160, 175]

# %%
df['height_cat'] = pd.cut(x=df.height, bins=(160, 175, 180, 195), labels=['small', 'medium', 'high'])
df
# Out:
#    height height_cat
# 0   175.0      small
# 1   178.5     medium
# 2   185.0       high
# 3   191.0       high
# 4   184.5       high
# 5   183.0       high
# 6   168.0      small

# %%
pd.get_dummies(df, drop_first=True, prefix='height')
# Out:
#    height  height_medium  height_high
# 0   175.0          False        False
# 1   178.5           True        False
# 2   185.0          False         True
# 3   191.0          False         True
# 4   184.5          False         True
# 5   183.0          False         True
# 6   168.0          False        False

# %% [markdown]
# ### <a name='5'></a> Ekstrakcja cech

# %%
df = pd.DataFrame(data={'lang': [['PL', 'ENG'], ['GER', 'ENG', 'PL', 'FRA'], ['RUS']]})
df
# Out:
#                   lang
# 0            [PL, ENG]
# 1  [GER, ENG, PL, FRA]
# 2                [RUS]

# %%
df['lang_number'] = df['lang'].apply(len)
df
# Out:
#                   lang  lang_number
# 0            [PL, ENG]            2
# 1  [GER, ENG, PL, FRA]            4
# 2                [RUS]            1

# %%
df['PL_flag'] = df['lang'].apply(lambda x: 1 if 'PL' in x else 0)
df
# Out:
#                   lang  lang_number  PL_flag
# 0            [PL, ENG]            2        1
# 1  [GER, ENG, PL, FRA]            4        1
# 2                [RUS]            1        0

# %%
df = pd.DataFrame(data={'website': ['wp.pl', 'onet.pl', 'google.com']})
df
# Out:
#       website
# 0       wp.pl
# 1     onet.pl
# 2  google.com

# %%
df.website.str.split('.', expand=True)
# Out:
#         0    1
# 0      wp   pl
# 1    onet   pl
# 2  google  com

# %%
new = df.website.str.split('.', expand=True)
df['portal'] = new[0]
df['extension'] = new[1]
df
# Out:
#       website  portal extension
# 0       wp.pl      wp        pl
# 1     onet.pl    onet        pl
# 2  google.com  google       com
